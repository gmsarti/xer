# %% [markdown]
# # Análise dos Contos
#
# Este notebook demonstra como conectar ao banco de dados SQLite `contos.db`, carregar as tabelas em `pandas` e fazer análises exploratórias básicas.
#
# > **Nota:** Substitua os nomes de tabelas/colunas conforme o seu esquema.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style="whitegrid")

# %%
# Caminho para o banco de dados (assumindo que está na pasta data)
db_path = '../data/contos.db'
conn = sqlite3.connect(db_path)

# %%
# Listar as tabelas disponíveis
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql_query(tables_query, conn)
print('Tabelas encontradas:')
print(tables['name'].tolist())
# Out:
# Tabelas encontradas:
# []

# %%
# Carregar a tabela principal (substitua 'contos' pelo nome real)
table_name = 'contos'  # <-- ajuste se necessário
df = pd.read_sql_query(f'SELECT * FROM {table_name}', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Work/code/xer/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: contos
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Carregar a tabela principal (substitua 'contos' pelo nome real)
#       2 table_name = 'contos'  # <-- ajuste se necessário
# ----> 3 df = pd.read_sql_query(f'SELECT * FROM {table_name}', conn)
#
# File ~/Work/code/xer/.venv/lib/python3.11/site-packages/pandas/io/sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File ~/Work/code/xer/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/Work/code/xer/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM contos': no such table: contos

# %%
# Visualizar as primeiras linhas
df.head()

# %%
# Estatísticas descritivas básicas
df.describe(include='all')

# %%
# Exemplo de visualização: distribuição do tamanho dos contos (supondo coluna 'texto')
if 'texto' in df.columns:
    df['tamanho'] = df['texto'].str.len()
    plt.figure(figsize=(8,5))
    sns.histplot(df['tamanho'], bins=30, kde=True)
    plt.title('Distribuição do tamanho dos contos')
    plt.xlabel('Número de caracteres')
    plt.show()
else:
    print('Coluna "texto" não encontrada. Ajuste o nome da coluna conforme seu esquema.')
